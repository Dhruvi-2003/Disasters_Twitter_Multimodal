# %%
import pandas as pd
import os

# %%
# df = pd.read_csv("..\CrisisMMD_v2.0\crisismmd_datasplit_all.zip\crisismmd_datasplit_all\task_damage_text_img_dev.tsv", sep = '\t')
os.chdir("D:\PS-1\crisismmd_datasplit_all")

# %%
df = pd.read_csv("task_informative_text_img_dev.tsv", sep='\t')
df
# Out:
#                 event_name            tweet_id              image_id  \
# 0     iraq_iran_earthquake  931465546129989632  931465546129989632_0
# 1         hurricane_harvey  905064623199719425  905064623199719425_0
# 2          hurricane_maria  922857566220283904  922857566220283904_0
# 3           hurricane_irma  909767231411769344  909767231411769344_0
# 4     california_wildfires  920571592131915777  920571592131915777_0
# ...                    ...                 ...                   ...
# 2232       hurricane_maria  921842963843551233  921842963843551233_0
# 2233     mexico_earthquake  910658635851644928  910658635851644928_0
# 2234      hurricane_harvey  906341151061499910  906341151061499910_0
# 2235       hurricane_maria  928822277067636737  928822277067636737_0
# 2236       hurricane_maria  913401831031820288  913401831031820288_0
#
#                                              tweet_text  \
# 0     #Iran #earthquake damage put at over 5bn pound...
# ...

# %%
import torch

# %%
model = torch.hub.load('saahiluppal/catr', 'v3', pretrained = True)
# !git clone https://github.com/saahiluppal/catr.git
# !pip install -r catr/requirements.txt
# Out:
# Using cache found in C:\Users\dhruv kamra/.cache\torch\hub\saahiluppal_catr_master
# C:\Users\dhruv kamra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\dhruv kamra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to C:\Users\dhruv kamra/.cache\torch\hub\checkpoints\resnet101-63fe2227.pth
# ...

# %%
# !pip install torchvision
# Out:
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#                                               0.0/1.2 MB ? eta -:--:--
#                                               0.0/1.2 MB ? eta -:--:--
#                                               0.0/1.2 MB ? eta -:--:--
#                                               0.0/1.2 MB ? eta -:--:--
#                                               0.0/1.2 MB ? eta -:--:--
#                                               0.0/1.2 MB ? eta -:--:--
#      -                                        0.0/1.2 MB 330.3 kB/s eta 0:00:04
#      -                                        0.0/1.2 MB 330.3 kB/s eta 0:00:04
#      -                                        0.0/1.2 MB 330.3 kB/s eta 0:00:04
#      -                                        0.0/1.2 MB 330.3 kB/s eta 0:00:04
#      -                                        0.0/1.2 MB 330.3 kB/s eta 0:00:04
# ...

# %%
# !python catr/caption_multiple.py --path data_image/california_wildfires/10_10_2017
# Out:
# Error for data_image\california_wildfires\10_10_2017\917791044158185473_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917791130590183424_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917791291823591425_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917791291823591425_1.jpg
# Error for data_image\california_wildfires\10_10_2017\917792092100988929_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917792147700465664_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917792930315821057_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917793137925459968_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917793137925459968_1.jpg
# Error for data_image\california_wildfires\10_10_2017\917793137925459968_2.jpg
# Error for data_image\california_wildfires\10_10_2017\917793158251077632_0.jpg
# Error for data_image\california_wildfires\10_10_2017\917793736918216706_0.jpg
# ...

# %%
# !python catr/predict.py --path data_image\california_wildfires\10_10_2017\917791044158185473_0.jpg
# Out:
# Using cache found in C:\Users\dhruv kamra/.cache\torch\hub\saahiluppal_catr_master
# C:\Users\dhruv kamra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\dhruv kamra\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Traceback (most recent call last):
#   File "D:\PS-1\catr\predict.py", line 47, in <module>
#     image = coco.val_transform(image)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
